# %%
from firecrawl import FirecrawlApp

# %%
# Initialize with your API key
app = FirecrawlApp(api_key="fc-22cb1fc9e8ec444fa3ef8a735b4693eb")

# Crawl the entire website
crawl_status = app.crawl_url(
    'https://bharathatechno.com/',
    params={
        'limit': 100,  # Limit to 100 pages to save free credits
        'scrapeOptions': {
            'formats': ['markdown'] # Markdown is best for chatbots
        }
    }
)

print(f"Crawl ID: {crawl_status['id']}")
